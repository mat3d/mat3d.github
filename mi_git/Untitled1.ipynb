# %%
print("dime la base:")
base = int(input())
print("dime la altura:")
altura = int(input())
print("El área es:")
print(base*altura/2)
# Out:
# dime la base:
# 10
# dime la altura:
# 10
# El área es:
# 50.0

# %%
from sympy import init_session
init_session()
# Out:
# IPython console for SymPy 1.2 (Python 3.6.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at http://docs.sympy.org/1.2/

# %%
solve(x-1)
# Out:
# [1]

# %%
expr=x**2
expr.diff()
# Out:
# 2⋅x

# %%
solve(Eq(3*x**8+5,6))
# Out:
# ⎡  7/8    7/8    7/8      7/8          7/8       7/8          7/8       7/8
# ⎢-3      3     -3   ⋅ⅈ   3   ⋅ⅈ    √2⋅3      √2⋅3   ⋅ⅈ    √2⋅3      √2⋅3   ⋅ⅈ
# ⎢──────, ────, ────────, ──────, - ─────── - ─────────, - ─────── + ─────────,
# ⎣  3      3       3        3          6          6           6          6
#
#      7/8       7/8        7/8       7/8  ⎤
#  √2⋅3      √2⋅3   ⋅ⅈ  √2⋅3      √2⋅3   ⋅ⅈ⎥
#  ─────── - ─────────, ─────── + ─────────⎥
#     6          6         6          6    ⎦

# %%
solve(Eq(mi vida))
# Out:
#   File "<ipython-input-39-6bb78ff01265>", line 1
#     solve(Eq(mi vida))
#                    ^
# SyntaxError: invalid syntax

# %%
pprint(solve(3*x**3+5-6))
# Out:
# ⎡ 2/3     2/3   6 ___       2/3   6 ___  ⎤
# ⎢3       3      ╲╱ 3 ⋅ⅈ    3      ╲╱ 3 ⋅ⅈ⎥
# ⎢────, - ──── - ───────, - ──── + ───────⎥
# ⎣ 3       6        2        6        2   ⎦

# %%
plot(x**2)

# %%
plot(sin(x**2))

# %%
plot
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-f89d96586aed> in <module>()
# ----> 1 plot(tan(x**sin))
#
# ~/Mis_aplicaciones/anaconda3/lib/python3.6/site-packages/sympy/core/expr.py in __pow__(self, other, mod)
#     152     def __pow__(self, other, mod=None):
#     153         if mod is None:
# --> 154             return self._pow(other)
#     155         try:
#     156             _self, other, mod = as_int(self), as_int(other), as_int(mod)
#
# ~/Mis_aplicaciones/anaconda3/lib/python3.6/site-packages/sympy/core/decorators.py in __sympifyit_wrapper(a, b)
#      89                 if not hasattr(b, '_op_priority'):
#      90                     b = sympify(b, strict=True)
# ---> 91                 return func(a, b)
#      92             except SympifyError:
#      93                 return retval
#
# ...
